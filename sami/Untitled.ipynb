# %%
# -*- coding: utf-8 -*-
"""
Spyder Editor

This is a temporary script file.
"""

import numpy as np
import os 
import scipy.special as sp
import scipy as spx
import scipy.optimize as op
import matplotlib.pyplot as mpl
from sklearn.metrics import mean_squared_error 

def ob(beta,x,v,t):    
    pos_beta = abs(beta)
    print(f'beta val = {beta}')
    part1 = sp.erfc((x-(v*t)/(2.*np.sqrt(pos_beta*v*t))))
    part2 = np.exp((v*x)/(pos_beta*v))
    part3 = sp.erfc((x+(v*t)/(2.*np.sqrt(pos_beta*v*t))))
    conc = 0.5*(part1+(part2*part3))
    print(f'calculted conc = {conc}')
    return conc

def rmse(beta,x,v,t,c):
    
    c2 = ob(beta,x,v,t)
    #rm = np.sqrt(np.square(np.subtract(c2,c)).mean() )
    rm =np.sqrt( mean_squared_error(c,c2)) 
    print(f'calculated rm = {rm}')
    return rm       

def opt_beta(beta,x,v,t,c):
    out = op.minimize(rmse,beta,args=(x,v,t,c),method = 'Nelder-Mead', options = {'xtol':1e-4, 'disp':False },bounds = ((0, None),))
    print(out.x)
    return out.x



def plot_output(t,conc,conc2):
    print('inside plot')
    mpl.close('all')
    mpl.figure()
    mpl.plot(t,conc,linewidth=2,label='Data')
    mpl.plot(t,conc2,linewidth=1,label='Guess')
    #mpl.plot(t,conc3,linewidth=1,label='fit')
    mpl.legend(frameon=False)
    mpl.xlabel('time (d)')
    mpl.ylabel('Concentration (-)')
    mpl.show()



def main():
    print("++++++++++Main+++++++++++++")
    #data_path = ".\\python-task\\"
    beta = 0.0395000
    f= "D:\\Zohaib\\Fivrr\\sami\\python-task\\A\\01\\HeatSolo.observation_well_conc.005.solute.dat"
    data = np.genfromtxt(f,skip_header=2)
    x= data[0,2]
    print(f'x= {x}')
    t= data[:,0]/86400
    print(f't= {t}')
    c= data[:,1]
    print(f'c= {c}')
    arrpos = np.argmax(c>0.5)
    v=x/t[arrpos]
    c2 = ob(beta,x,v,t)
    #betafit = opt_beta(beta,x,v,t,c)
    #c3 = ob(betafit,x,v,t)
    plot_output(t,c,c2)


    # for subdirs,dirs,files in os.walk(data_path):  
    #    for fname in files: 
    #         print('++++++++inside for+++++++++')
    #         f = subdirs+'\\'+fname
    #         print(f)
    #         data = np.genfromtxt(f,skip_header=2)
    #         x= data[0,2]
    #         t= data[:,0]/86400
    #         print(t)
    #         c= data[:,1]
    #         arrpos = np.argmax(c>0.5)
    #         v=x/t[arrpos]
    #         c2 = ob(beta,x,v,t)
    #         #betafit = opt_beta(beta,x,v,t,c)
    #         #c3 = ob(betafit,x,v,t)
    #         plot_output(t,c,c2)

    
    
if __name__ == '__main__':
    main()
# Out:
# ++++++++++Main+++++++++++++
# x= 25.0
# t= [5.00000000e-02 1.02500000e-01 1.57625000e-01 ... 9.48716135e+02
#  9.48916135e+02 9.49074074e+02]
# c= [7.2853e-121 1.6059e-112 2.1679e-106 ... 1.0000e+000 1.0000e+000
#  1.0000e+000]
# beta val = 0.0395
# calculted conc = [5.97477525e-07 2.58972206e-10 5.26643588e-13 ... 1.00000000e+00
#  1.00000000e+00 1.00000000e+00]
# inside plot
